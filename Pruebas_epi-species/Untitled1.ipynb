# %%
import requests
import json
import math
import copy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import rasterio as rio
import shapefile
import geopandas as gpd
import os
import fiona

# %%
dr = 'snib_mapa_shapefile.shp'
mexico_shapefile = gpd.read_file(dr)
mexico_shapefile.plot()
plt.show()

# %%
print(mexico_shapefile.head())
# Out:
#    OBJECTID CVE_ENT         NOM_ENT CVE_MUN                    NOM_MUN CVEGEO  \
# 0         1      01  Aguascalientes     002                   Asientos  01002
# 1         2      01  Aguascalientes     011  San Francisco de los Romo  01011
# 2         3      01  Aguascalientes     007           RincÃ³n de Romos  01007
# 3         4      01  Aguascalientes     008        San JosÃ© de Gracia  01008
# 4         5      01  Aguascalientes     005              JesÃºs MarÃ­a  01005
#
#           AREA  PERIMETER  COV_  COV_ID gridid    tscore  decil  \
# 0  54337.42658  192.09643   0.0     1.0  01002 -4.869469      1
# 1  13777.01765  103.68906   1.0     2.0  01011 -6.844338      1
# 2  37229.51619  161.74988   2.0     3.0  01007 -2.915521      1
# 3  85779.05758  181.53760   3.0     4.0  01008  7.362441      7
# 4  49989.50925  163.50081   4.0     5.0  01005  8.331381      7
#
#                                             geometry
# 0  POLYGON ((-101.99941 22.21951, -101.99940 22.2...
# 1  POLYGON ((-102.14088 22.07534, -102.14086 22.0...
# 2  POLYGON ((-102.18902 22.36244, -102.18951 22.3...
# 3  POLYGON ((-102.35385 22.12064, -102.35426 22.1...
# 4  POLYGON ((-102.31034 22.03716, -102.30653 22.0...
